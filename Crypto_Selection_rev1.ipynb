# %% [markdown]
# # Notebook dedicado à seleção das cryptos que serão candidatas a indicação ao cliente e ao carregamento dos dados relativos a preços e volumes

# %% [markdown]
# # 1. Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import yfinance as yf
import datetime as dt

# %%
#Vamos precisar também da API da Coin Market Cap para baixar a lista de IDs disponíveis:
#!pip install python-coinmarketcap

# %%
import coinmarketcapapi

# %% [markdown]
# # 2. Carregamento dos dados gerais

# %% [markdown]
# Vamos usar a API do CoinMarketCap para puxar os criptoativos disponíveis hoje. Porém, como o uso da plataforma free é limitado a alguns créditos por mês e os valores históricos são acessíveis somente com API paga, vamos deixar essa segunda parte com o Yfinance.

# %%
key = "f07f99c4-b668-44d9-8ccd-08107b1eecac"
cmc = coinmarketcapapi.CoinMarketCapAPI(key)

# %%
data_id_map = cmc.cryptocurrency_map()

# %%
df_info = pd.DataFrame(data_id_map.data, columns =['name','symbol','rank','is_active','first_historical_data'])
df_info.set_index('symbol',inplace=True)
df_info
# Out:
#                         name  rank  is_active     first_historical_data
# symbol
# BTC                  Bitcoin     1          1  2013-04-28T18:47:21.000Z
# LTC                 Litecoin    16          1  2013-04-28T18:47:22.000Z
# NMC                 Namecoin   741          1  2013-04-28T18:47:22.000Z
# TRC                Terracoin  1856          1  2013-04-28T18:47:22.000Z
# PPC                 Peercoin   662          1  2013-04-28T18:47:23.000Z
# ...                      ...   ...        ...                       ...
# CRP           CropperFinance  3315          1  2021-08-25T01:12:21.000Z
# DIAMONDHANDS   DIAMOND HANDS  3541          1  2021-08-25T03:45:21.000Z
# HIBIKI        Hibiki Finance  3049          1  2021-08-25T04:18:18.000Z
# ONE1INCH        Stable 1inch  4620          1  2021-08-25T08:57:22.000Z
# AAA              Moon Rabbit  3578          1  2021-08-25T08:55:11.000Z
#
# [6147 rows x 4 columns]

# %% [markdown]
# # 3. Seleção das Cryptos

# %% [markdown]
# Temos os símbolos, nomes, rank por MarketCap, informação sobre atividade ou não e também a data da primeira cotação, para mais de 6k ativos.

# %% [markdown]
# Vamos filtrar apenas pelos assets ainda ativos hoje:

# %%
df_info[df_info['is_active']==1]
# Out:
#                         name  rank  is_active     first_historical_data
# symbol
# BTC                  Bitcoin     1          1  2013-04-28T18:47:21.000Z
# LTC                 Litecoin    16          1  2013-04-28T18:47:22.000Z
# NMC                 Namecoin   741          1  2013-04-28T18:47:22.000Z
# TRC                Terracoin  1856          1  2013-04-28T18:47:22.000Z
# PPC                 Peercoin   662          1  2013-04-28T18:47:23.000Z
# ...                      ...   ...        ...                       ...
# CRP           CropperFinance  3315          1  2021-08-25T01:12:21.000Z
# DIAMONDHANDS   DIAMOND HANDS  3541          1  2021-08-25T03:45:21.000Z
# HIBIKI        Hibiki Finance  3049          1  2021-08-25T04:18:18.000Z
# ONE1INCH        Stable 1inch  4620          1  2021-08-25T08:57:22.000Z
# AAA              Moon Rabbit  3578          1  2021-08-25T08:55:11.000Z
#
# [6147 rows x 4 columns]

# %% [markdown]
# Todos os assets estão ativos (é muita moeda...). Como temos o rank por MarketCap, vamos selecionar as 50 moedas com maior valor de mercado hoje:

# %%
df_info_top = df_info[df_info['rank'] <= 50 ].sort_values(by='rank', ascending=True)
df_info_top
# Out:
#                      name  rank  is_active     first_historical_data
# symbol
# BTC               Bitcoin     1          1  2013-04-28T18:47:21.000Z
# ETH              Ethereum     2          1  2015-08-07T14:49:30.000Z
# ADA               Cardano     3          1  2017-10-01T20:34:25.000Z
# BNB          Binance Coin     4          1  2017-07-25T04:30:05.000Z
# USDT               Tether     5          1  2015-02-25T13:34:26.000Z
# XRP                   XRP     6          1  2013-08-04T18:51:05.000Z
# DOGE             Dogecoin     7          1  2013-12-15T14:42:34.000Z
# USDC             USD Coin     8          1  2018-10-08T18:49:28.000Z
# DOT              Polkadot     9          1  2020-08-20T03:29:22.000Z
# SOL                Solana    10          1  2020-04-10T04:59:18.000Z
# UNI               Uniswap    11          1  2020-09-17T01:14:14.000Z
# BUSD          Binance USD    12          1  2019-09-20T08:34:14.000Z
# BCH          Bitcoin Cash    13          1  2017-07-23T16:29:27.000Z
# LUNA                Terra    14          1  2019-07-26T01:09:11.000Z
# LINK            Chainlink    15          1  2017-09-20T20:54:59.000Z
# LTC              Litecoin    16          1  2013-04-28T18:47:22.000Z
# WBTC      Wrapped Bitcoin    17          1  2019-01-30T18:19:09.000Z
# MATIC             Polygon    18          1  2019-04-28T20:04:10.000Z
# ICP     Internet Computer    19          1  2021-05-10T11:03:07.000Z
# AVAX            Avalanche    20          1  2020-09-22T06:44:00.000Z
# XLM               Stellar    21          1  2014-08-05T05:44:19.000Z
# ETC      Ethereum Classic    22          1  2016-07-24T13:44:30.000Z
# VET               VeChain    23          1  2018-08-03T17:04:23.000Z
# FIL              Filecoin    24          1  2017-12-13T20:40:00.000Z
# THETA               THETA    25          1  2018-01-17T17:34:26.000Z
# DAI                   Dai    26          1  2019-11-22T01:59:14.000Z
# TRX                  TRON    27          1  2017-09-13T01:15:22.000Z
# XMR                Monero    28          1  2014-05-21T01:41:13.000Z
# CAKE          PancakeSwap    29          1  2020-09-28T07:55:00.000Z
# AAVE                 Aave    30          1  2020-10-04T12:56:22.000Z
# EOS                   EOS    31          1  2017-07-01T19:14:14.000Z
# FTT             FTX Token    32          1  2019-07-31T21:39:04.000Z
# AXS         Axie Infinity    33          1  2020-11-03T13:10:00.000Z
# GRT             The Graph    34          1  2020-12-17T18:00:07.000Z
# ATOM               Cosmos    35          1  2019-03-14T20:44:09.000Z
# KLAY               Klaytn    36          1  2020-03-30T04:19:07.000Z
# CRO       Crypto.com Coin    37          1  2018-12-14T17:39:38.000Z
# NEO                   Neo    38          1  2016-09-09T03:09:33.000Z
# BTCB         Bitcoin BEP2    39          1  2019-06-18T20:24:11.000Z
# MKR                 Maker    40          1  2017-01-29T19:19:37.000Z
# XTZ                 Tezos    41          1  2017-10-02T15:59:43.000Z
# ALGO             Algorand    42          1  2019-06-21T00:14:12.000Z
# BSV            Bitcoin SV    43          1  2018-11-09T02:34:34.000Z
# LEO          UNUS SED LEO    44          1  2019-05-21T18:39:12.000Z
# SHIB            SHIBA INU    45          1  2020-08-01T00:19:18.000Z
# MIOTA                IOTA    46          1  2017-06-13T14:30:09.000Z
# BTT            BitTorrent    47          1  2019-01-31T18:19:07.000Z
# EGLD               Elrond    48          1  2020-09-04T09:29:47.000Z
# AMP                   Amp    49          1  2020-09-11T04:34:18.000Z
# DASH                 Dash    50          1  2014-02-14T13:44:09.000Z

# %% [markdown]
# Agora, vamos admitir somente aquelas cryptos que possuem disponibilidade de dados maior do que 3 anos, ou seja, que foram listadas antes de 01/08/2018:

# %%
df_eligible = df_info_top[df_info_top['first_historical_data']<="2018-08-01"]
df_eligible
# Out:
#                     name  rank  is_active     first_historical_data
# symbol
# BTC              Bitcoin     1          1  2013-04-28T18:47:21.000Z
# ETH             Ethereum     2          1  2015-08-07T14:49:30.000Z
# ADA              Cardano     3          1  2017-10-01T20:34:25.000Z
# BNB         Binance Coin     4          1  2017-07-25T04:30:05.000Z
# USDT              Tether     5          1  2015-02-25T13:34:26.000Z
# XRP                  XRP     6          1  2013-08-04T18:51:05.000Z
# DOGE            Dogecoin     7          1  2013-12-15T14:42:34.000Z
# BCH         Bitcoin Cash    13          1  2017-07-23T16:29:27.000Z
# LINK           Chainlink    15          1  2017-09-20T20:54:59.000Z
# LTC             Litecoin    16          1  2013-04-28T18:47:22.000Z
# XLM              Stellar    21          1  2014-08-05T05:44:19.000Z
# ETC     Ethereum Classic    22          1  2016-07-24T13:44:30.000Z
# FIL             Filecoin    24          1  2017-12-13T20:40:00.000Z
# THETA              THETA    25          1  2018-01-17T17:34:26.000Z
# TRX                 TRON    27          1  2017-09-13T01:15:22.000Z
# XMR               Monero    28          1  2014-05-21T01:41:13.000Z
# EOS                  EOS    31          1  2017-07-01T19:14:14.000Z
# NEO                  Neo    38          1  2016-09-09T03:09:33.000Z
# MKR                Maker    40          1  2017-01-29T19:19:37.000Z
# XTZ                Tezos    41          1  2017-10-02T15:59:43.000Z
# MIOTA               IOTA    46          1  2017-06-13T14:30:09.000Z
# DASH                Dash    50          1  2014-02-14T13:44:09.000Z

# %%
df_eligible.shape
# Out:
# (22, 4)

# %% [markdown]
# Para preparar o df para o carregamento das informações de preço através do yahoo finance, precisamos que as moedas terminem com o sufixo -USD. Vamos fazer isso em nova coluna:

# %%
df_eligible['ticker'] = df_eligible.index + "-USD"
df_eligible
# Out:
# <ipython-input-12-f2dfc713904d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eligible['ticker'] = df_eligible.index + "-USD"
#                     name  rank  is_active     first_historical_data     ticker
# symbol
# BTC              Bitcoin     1          1  2013-04-28T18:47:21.000Z    BTC-USD
# ETH             Ethereum     2          1  2015-08-07T14:49:30.000Z    ETH-USD
# ADA              Cardano     3          1  2017-10-01T20:34:25.000Z    ADA-USD
# BNB         Binance Coin     4          1  2017-07-25T04:30:05.000Z    BNB-USD
# USDT              Tether     5          1  2015-02-25T13:34:26.000Z   USDT-USD
# XRP                  XRP     6          1  2013-08-04T18:51:05.000Z    XRP-USD
# DOGE            Dogecoin     7          1  2013-12-15T14:42:34.000Z   DOGE-USD
# BCH         Bitcoin Cash    13          1  2017-07-23T16:29:27.000Z    BCH-USD
# LINK           Chainlink    15          1  2017-09-20T20:54:59.000Z   LINK-USD
# LTC             Litecoin    16          1  2013-04-28T18:47:22.000Z    LTC-USD
# XLM              Stellar    21          1  2014-08-05T05:44:19.000Z    XLM-USD
# ETC     Ethereum Classic    22          1  2016-07-24T13:44:30.000Z    ETC-USD
# FIL             Filecoin    24          1  2017-12-13T20:40:00.000Z    FIL-USD
# THETA              THETA    25          1  2018-01-17T17:34:26.000Z  THETA-USD
# TRX                 TRON    27          1  2017-09-13T01:15:22.000Z    TRX-USD
# XMR               Monero    28          1  2014-05-21T01:41:13.000Z    XMR-USD
# EOS                  EOS    31          1  2017-07-01T19:14:14.000Z    EOS-USD
# NEO                  Neo    38          1  2016-09-09T03:09:33.000Z    NEO-USD
# MKR                Maker    40          1  2017-01-29T19:19:37.000Z    MKR-USD
# XTZ                Tezos    41          1  2017-10-02T15:59:43.000Z    XTZ-USD
# MIOTA               IOTA    46          1  2017-06-13T14:30:09.000Z  MIOTA-USD
# DASH                Dash    50          1  2014-02-14T13:44:09.000Z   DASH-USD

# %% [markdown]
# ## Resumo da estratégia de seleção:

# %% [markdown]
# - Escolhemos apenas cryptoassets que estejam ativos ainda hoje (6.124);
# - Filtramos pelos 50 maiores ativos, por ordem de tamanho de mercado;
# - Excluímos aqueles com menos de 3 anos de mercado, para termos dados suficientes para fazer as projeções.
# - Terminamos com 22 ativos.

# %% [markdown]
# # 4. Carregamento de dados

# %% [markdown]
# ## Carregamento de market cap, após seleção das cryptos - YFinance

# %%
for ativo in df_eligible.index:
    df_eligible.loc[ativo,'marketCap'] = yf.Ticker(ativo+"-USD").info['marketCap']
# Out:
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#Vamos deixar o marketCap em bilhões de dólares:
df_eligible['marketCap_1E9'] = df_eligible['marketCap']/1e9
df_eligible.drop(columns = ['marketCap'], inplace=True)
df_eligible['first_historical_data'] = pd.to_datetime(df_eligible['first_historical_data'])
df_eligible
# Out:
# <ipython-input-14-305ebdddcd89>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eligible['marketCap_1E9'] = df_eligible['marketCap']/1e9
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-14-305ebdddcd89>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eligible['first_historical_data'] = pd.to_datetime(df_eligible['first_historical_data'])
#                     name  rank  is_active     first_historical_data  \
# symbol
# BTC              Bitcoin     1          1 2013-04-28 18:47:21+00:00
# ETH             Ethereum     2          1 2015-08-07 14:49:30+00:00
# ADA              Cardano     3          1 2017-10-01 20:34:25+00:00
# BNB         Binance Coin     4          1 2017-07-25 04:30:05+00:00
# USDT              Tether     5          1 2015-02-25 13:34:26+00:00
# XRP                  XRP     6          1 2013-08-04 18:51:05+00:00
# DOGE            Dogecoin     7          1 2013-12-15 14:42:34+00:00
# BCH         Bitcoin Cash    13          1 2017-07-23 16:29:27+00:00
# LINK           Chainlink    15          1 2017-09-20 20:54:59+00:00
# LTC             Litecoin    16          1 2013-04-28 18:47:22+00:00
# XLM              Stellar    21          1 2014-08-05 05:44:19+00:00
# ETC     Ethereum Classic    22          1 2016-07-24 13:44:30+00:00
# FIL             Filecoin    24          1 2017-12-13 20:40:00+00:00
# THETA              THETA    25          1 2018-01-17 17:34:26+00:00
# TRX                 TRON    27          1 2017-09-13 01:15:22+00:00
# XMR               Monero    28          1 2014-05-21 01:41:13+00:00
# EOS                  EOS    31          1 2017-07-01 19:14:14+00:00
# NEO                  Neo    38          1 2016-09-09 03:09:33+00:00
# MKR                Maker    40          1 2017-01-29 19:19:37+00:00
# XTZ                Tezos    41          1 2017-10-02 15:59:43+00:00
# MIOTA               IOTA    46          1 2017-06-13 14:30:09+00:00
# DASH                Dash    50          1 2014-02-14 13:44:09+00:00
#
#            ticker  marketCap_1E9
# symbol
# BTC       BTC-USD     892.588917
# ETH       ETH-USD     365.700252
# ADA       ADA-USD      85.157462
# BNB       BNB-USD      80.098329
# USDT     USDT-USD      65.478918
# XRP       XRP-USD      52.557361
# DOGE     DOGE-USD      37.115589
# BCH       BCH-USD      11.886005
# LINK     LINK-USD      11.498951
# LTC       LTC-USD      11.457791
# XLM       XLM-USD       8.160446
# ETC       ETC-USD       7.986605
# FIL       FIL-USD       7.282532
# THETA   THETA-USD       6.913782
# TRX       TRX-USD       6.006697
# XMR       XMR-USD       5.439089
# EOS       EOS-USD       4.777306
# NEO       NEO-USD       3.787587
# MKR       MKR-USD       3.515242
# XTZ       XTZ-USD       3.496038
# MIOTA   MIOTA-USD       2.850678
# DASH     DASH-USD       2.489007

# %% [markdown]
# ## Carregando e salvando os dados de preço e volume por ativo após seleção das cryptos

# %%
#Vamos acessar os dados de cada ativo, exportando-os para arquivos csv específicos e juntando tudo num dataframe único, o df_ativos.
#O df_ativos também será salvo ao final.

final = dt.datetime(2021,8,20)
path = r"C:\Users\Alexandre\OneDrive\Documentos\1. PRO\Data Science\Projeto Integrador\Dados\cryptos"
extension = ".csv"

df_ativos = pd.DataFrame(columns = ['Ativo', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])

for ativo in df_eligible.ticker:
     
    inicio = df_eligible.loc[ativo[:-4],['first_historical_data']][0]
    print(f"Iniciando coleta do ativo {ativo} desde {inicio}")
    
    dados = yf.download(ativo, inicio, final)
    dados['Ativo'] = ativo
    
    file = str(ativo)
    
    dados.to_csv(path + "\\" + file + extension)
    
    df_ativos = pd.concat([df_ativos, dados])
# Out:
# Iniciando coleta do ativo BTC-USD desde 2013-04-28 18:47:21+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo ETH-USD desde 2015-08-07 14:49:30+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo ADA-USD desde 2017-10-01 20:34:25+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo BNB-USD desde 2017-07-25 04:30:05+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo USDT-USD desde 2015-02-25 13:34:26+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo XRP-USD desde 2013-08-04 18:51:05+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo DOGE-USD desde 2013-12-15 14:42:34+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo BCH-USD desde 2017-07-23 16:29:27+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo LINK-USD desde 2017-09-20 20:54:59+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo LTC-USD desde 2013-04-28 18:47:22+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo XLM-USD desde 2014-08-05 05:44:19+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo ETC-USD desde 2016-07-24 13:44:30+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo FIL-USD desde 2017-12-13 20:40:00+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo THETA-USD desde 2018-01-17 17:34:26+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo TRX-USD desde 2017-09-13 01:15:22+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo XMR-USD desde 2014-05-21 01:41:13+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo EOS-USD desde 2017-07-01 19:14:14+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo NEO-USD desde 2016-09-09 03:09:33+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo MKR-USD desde 2017-01-29 19:19:37+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo XTZ-USD desde 2017-10-02 15:59:43+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo MIOTA-USD desde 2017-06-13 14:30:09+00:00
# [*********************100%***********************]  1 of 1 completed
# Iniciando coleta do ativo DASH-USD desde 2014-02-14 13:44:09+00:00
# [*********************100%***********************]  1 of 1 completed

# %%
df_ativos
# Out:
#                Ativo        Open        High         Low       Close  \
# 2014-09-17   BTC-USD  465.864014  468.174011  452.421997  457.334015
# 2014-09-18   BTC-USD  456.859985  456.859985  413.104004  424.440002
# 2014-09-19   BTC-USD  424.102997  427.834991  384.532013  394.795990
# 2014-09-20   BTC-USD  394.673004  423.295990  389.882996  408.903992
# 2014-09-21   BTC-USD  408.084991  412.425995  393.181000  398.821014
# ...              ...         ...         ...         ...         ...
# 2021-08-16  DASH-USD  215.874359  216.735474  199.934326  202.093277
# 2021-08-17  DASH-USD  201.299622  211.345093  186.345810  194.603912
# 2021-08-18  DASH-USD  194.697891  213.366608  187.295181  210.221527
# 2021-08-19  DASH-USD  209.888916  220.769531  199.233871  220.021484
# 2021-08-20  DASH-USD  219.971161  235.317276  218.387054  232.825378
#
#              Adj Close     Volume
# 2014-09-17  457.334015   21056800
# 2014-09-18  424.440002   34483200
# 2014-09-19  394.795990   37919700
# 2014-09-20  408.903992   36863600
# 2014-09-21  398.821014   26580100
# ...                ...        ...
# 2021-08-16  202.093277  355403656
# 2021-08-17  194.603912  424686878
# 2021-08-18  210.221527  432819051
# 2021-08-19  220.021484  397627914
# 2021-08-20  232.825378  502645254
#
# [41303 rows x 7 columns]

# %% [markdown]
# # 5. Armazenamento dos dados das cryptos escolhidas

# %% [markdown]
# Vamos salvar o df_eligible, com dados globais dos 22 ativos:

# %%
df_eligible.to_csv(r"C:\Users\Alexandre\OneDrive\Documentos\1. PRO\Data Science\Projeto Integrador\Dados\df_eligible.csv")

# %%
df_ativos.to_csv(r"C:\Users\Alexandre\OneDrive\Documentos\1. PRO\Data Science\Projeto Integrador\Dados\df_ativos.csv", index=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-29e5b1debf15> in <module>
# ----> 1 df_ativos.to_csv(r"C:\Users\Alexandre\OneDrive\Documentos\1. PRO\Data Science\Projeto Integrador\Dados\df_ativos.csv", index_label=df_ativos.index)
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3461         )
#    3462
# -> 3463         return DataFrameRenderer(formatter).to_csv(
#    3464             path_or_buf,
#    3465             line_terminator=line_terminator,
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     255             )
#     256
# --> 257             self._save()
#     258
#     259     def _save(self) -> None:
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     259     def _save(self) -> None:
#     260         if self._need_to_save_header:
# --> 261             self._save_header()
#     262         self._save_body()
#     263
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_header(self)
#     264     def _save_header(self) -> None:
#     265         if not self.has_mi_columns or self._has_aliases:
# --> 266             self.writer.writerow(self.encoded_labels)
#     267         else:
#     268             for row in self._generate_multiindex_header_rows():
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in encoded_labels(self)
#     221         encoded_labels: list[Hashable] = []
#     222
# --> 223         if self.index and self.index_label:
#     224             assert isinstance(self.index_label, Sequence)
#     225             encoded_labels = list(self.index_label)
#
# H:\Users\Alexandre\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __nonzero__(self)
#    2807     @final
#    2808     def __nonzero__(self):
# -> 2809         raise ValueError(
#    2810             f"The truth value of a {type(self).__name__} is ambiguous. "
#    2811             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DatetimeIndex is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
